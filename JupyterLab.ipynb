# %% [markdown]
# # Holidays

# %% [markdown]
# #### This notebook shows my holiday preference

# %% [markdown]
# ## Index
# [Name](#name)
#
# [Photo of Person](#photo1)
#
# [Location Preferences](#prefs)
#
# [Photo of Destination](#photo2)
#
# [Activities](#activities)
#
# [Video](#video)

# %% [markdown]
# <a id="name"></a>

# %%
name = input("Name: ")
# Out:
# Name: Emma

# %% [markdown]
# <a id="photo1"></a>

# %% [markdown]
# ![image0.jpeg](attachment:image0.jpeg)

# %% [markdown]
# <a id="prefs"></a>

# %%
pref_country = input("Country of holiday preference: ")
pref_city = input("City of holiday preference in that country: ")
# Out:
# Country of holiday preference: Austria
# City of holiday preference in that country: Ischgl

# %%
pref_country
# Out:
# 'Austria'

# %%
pref_city
# Out:
# 'Ischgl'

# %% [markdown]
# <a id="photo2"></a>

# %% [markdown]
# ![Screenshot%202021-10-18%20at%2016.32.11.png](attachment:Screenshot%202021-10-18%20at%2016.32.11.png)

# %% [markdown]
# <a id="activities"></a>

# %% [markdown]
# #### <i> Top 3 activities:<i>
# * <span style="color:orange">Skiing</span>
# - <span style="color:cyan">Eating</span>
# - <span style="color:pink">Drinking</span>

# %% [markdown]
# <a id="video"></a>

# %% [markdown]
# [Click here to see a video](https://www.youtube.com/watch?v=ljf1oEY9rAM&ab_channel=TheSkiClub)
